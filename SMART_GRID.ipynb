# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek3102/ML/blob/main/SMART_GRID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("/content/SMART_GRID_COMBINED.csv")

# %%
df
# Out:
#                    date        p1        p2        p3        c1        c2  \
# 0      01-01-2019 01:00  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1      01-01-2019 02:00  0.862414  0.562139  0.781760 -1.940058 -1.872742
# 2      01-01-2019 03:00  0.766689  0.839444  0.109853 -1.207456 -1.277210
# 3      01-01-2019 04:00  0.976744  0.929381  0.362718 -1.027473 -1.938944
# 4      01-01-2019 05:00  0.455450  0.656947  0.820923 -1.125531 -1.845975
# ...                 ...       ...       ...       ...       ...       ...
# 43818  31-12-2023 19:00  0.257940  0.895296  0.868929 -1.954289 -0.981347
# 43819  31-12-2023 20:00  0.848075  0.909264  0.266201 -1.428185 -0.525543
# 43820  31-12-2023 21:00  0.393902  0.441923  0.697164 -0.701491 -1.279522
# 43821  31-12-2023 22:00  0.280877  0.532758  0.368188 -1.076426 -1.231602
# 43822  31-12-2023 23:00  0.237036  0.891977  0.656815 -1.579196 -1.526573
#
#              c3 stability
# 0     -1.723086  unstable
# ...

# %%
df1 = pd.read_csv("/content/updated_combined_data2.csv")

# %%
df1
# Out:
#                    date        p1        p2        p3        c1        c2  \
# 0      01-01-2019 01:00  0.859578  0.887445  0.958034 -0.782604 -1.257395
# 1      01-01-2019 02:00  0.862414  0.562139  0.781760 -1.940058 -1.872742
# 2      01-01-2019 03:00  0.766689  0.839444  0.109853 -1.207456 -1.277210
# 3      01-01-2019 04:00  0.976744  0.929381  0.362718 -1.027473 -1.938944
# 4      01-01-2019 05:00  0.455450  0.656947  0.820923 -1.125531 -1.845975
# ...                 ...       ...       ...       ...       ...       ...
# 43818  31-12-2023 19:00  0.257940  0.895296  0.868929 -1.954289 -0.981347
# 43819  31-12-2023 20:00  0.848075  0.909264  0.266201 -1.428185 -0.525543
# 43820  31-12-2023 21:00  0.393902  0.441923  0.697164 -0.701491 -1.279522
# 43821  31-12-2023 22:00  0.280877  0.532758  0.368188 -1.076426 -1.231602
# 43822  31-12-2023 23:00  0.237036  0.891977  0.656815 -1.579196 -1.526573
#
#              c3  stability
# 0     -1.723086          1
# ...

# %%
import pandas as pd

# Load your dataset (replace 'your_dataset.csv' with the actual filename)
df = pd.read_csv('/content/updated_combined_data2.csv')

# Convert 'date' column from string to datetime
df1['date'] = pd.to_datetime(df1['date'], format='%d-%m-%Y')

# Convert datetime to string with the desired format
df1['date'] = df['date'].dt.strftime('%d.%m.%Y')

# Print the updated DataFrame to check
print(df1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-22c73c8b4302> in <cell line: 7>()
#       5
#       6 # Convert 'date' column from string to datetime
# ----> 7 df1['date'] = pd.to_datetime(df1['date'], format='%d-%m-%Y')
#       8
#       9 # Convert datetime to string with the desired format
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048             result = arg.map(cache_array)
#    1049         else:
# -> 1050             values = convert_listlike(arg._values, format)
#    1051             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ...

# %%
# Load your dataset (replace 'your_dataset.csv' with the actual filename)
df1 = pd.read_csv('/content/updated_combined_data2.csv')

# Convert 'date' column from string to datetime
df1['date'] = pd.to_datetime(df1['date'], format='%d-%m-%Y %H:%M')

# Convert datetime to string with the desired format
df1['date'] = df1['date'].dt.strftime('%d.%m.%Y')

# Print the updated DataFrame to check
print(df1)
# Out:
#              date        p1        p2        p3        c1        c2        c3  \
# 0      01.01.2019  0.859578  0.887445  0.958034 -0.782604 -1.257395 -1.723086
# 1      01.01.2019  0.862414  0.562139  0.781760 -1.940058 -1.872742 -1.255012
# 2      01.01.2019  0.766689  0.839444  0.109853 -1.207456 -1.277210 -0.920492
# 3      01.01.2019  0.976744  0.929381  0.362718 -1.027473 -1.938944 -0.997374
# 4      01.01.2019  0.455450  0.656947  0.820923 -1.125531 -1.845975 -0.554305
# ...           ...       ...       ...       ...       ...       ...       ...
# 43818  31.12.2023  0.257940  0.895296  0.868929 -1.954289 -0.981347 -1.654103
# 43819  31.12.2023  0.848075  0.909264  0.266201 -1.428185 -0.525543 -1.545585
# 43820  31.12.2023  0.393902  0.441923  0.697164 -0.701491 -1.279522 -1.019624
# 43821  31.12.2023  0.280877  0.532758  0.368188 -1.076426 -1.231602 -1.164986
# 43822  31.12.2023  0.237036  0.891977  0.656815 -1.579196 -1.526573 -0.571834
#
#        stability
# ...

# %%
df2 = pd.read_csv("/content/whole_merged_properly.csv")

# %%
df2
# Out:
#                   DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0      2019-01-01 01:00:00                  10.926          0.979103
# 1      2019-01-01 02:00:00                   9.919          0.979566
# 2      2019-01-01 03:00:00                   8.567          0.979937
# 3      2019-01-01 04:00:00                   7.877          0.980053
# 4      2019-01-01 05:00:00                   7.259          0.979867
# ...                    ...                     ...               ...
# 43818  2023-12-31 19:00:00                  11.713          0.985015
# 43819  2023-12-31 20:00:00                  12.115          0.985244
# 43820  2023-12-31 21:00:00                  11.856          0.985639
# 43821  2023-12-31 22:00:00                  10.761          0.986212
# 43822  2023-12-31 23:00:00                   8.380          0.987183
#
#        Wind speed | (m/s)  Power generated by system | (MW)
# 0                   9.014                           33.6881
# ...

# %%
# Remove leading and trailing pipe characters from column names
df.columns = df.columns.str.strip(" | ")

# %%
df2
# Out:
#                   DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0      2019-01-01 01:00:00                  10.926          0.979103
# 1      2019-01-01 02:00:00                   9.919          0.979566
# 2      2019-01-01 03:00:00                   8.567          0.979937
# 3      2019-01-01 04:00:00                   7.877          0.980053
# 4      2019-01-01 05:00:00                   7.259          0.979867
# ...                    ...                     ...               ...
# 43818  2023-12-31 19:00:00                  11.713          0.985015
# 43819  2023-12-31 20:00:00                  12.115          0.985244
# 43820  2023-12-31 21:00:00                  11.856          0.985639
# 43821  2023-12-31 22:00:00                  10.761          0.986212
# 43822  2023-12-31 23:00:00                   8.380          0.987183
#
#        Wind speed | (m/s)  Power generated by system | (MW)
# 0                   9.014                           33.6881
# ...

# %%
print(df2.columns)
print(df2.dtypes)
# Out:
# Index(['DateTime', 'Air temperature | (°C)', 'Pressure | (atm)',
#        'Wind speed | (m/s)', 'Power generated by system | (MW)'],
#       dtype='object')
# DateTime                             object
# Air temperature | (°C)              float64
# Pressure | (atm)                    float64
# Wind speed | (m/s)                  float64
# Power generated by system | (MW)    float64
# dtype: object

# %%
# Rename columns
df2.rename(columns={
    'Air temperature | (°C)': 'Air temperature (°C)',
    'Pressure | (atm)': 'Pressure (atm)',
    'Wind speed | (m/s)': 'Wind speed (m/s)',
    'Power generated by system | (MW)': 'Power generated by system (MW)'
}, inplace=True)

# %%
df2
# Out:
#                   DateTime  Air temperature (°C)  Pressure (atm)  \
# 0      2019-01-01 01:00:00                10.926        0.979103
# 1      2019-01-01 02:00:00                 9.919        0.979566
# 2      2019-01-01 03:00:00                 8.567        0.979937
# 3      2019-01-01 04:00:00                 7.877        0.980053
# 4      2019-01-01 05:00:00                 7.259        0.979867
# ...                    ...                   ...             ...
# 43818  2023-12-31 19:00:00                11.713        0.985015
# 43819  2023-12-31 20:00:00                12.115        0.985244
# 43820  2023-12-31 21:00:00                11.856        0.985639
# 43821  2023-12-31 22:00:00                10.761        0.986212
# 43822  2023-12-31 23:00:00                 8.380        0.987183
#
#        Wind speed (m/s)  Power generated by system (MW)
# 0                 9.014                         33.6881
# 1                 9.428                         37.2619
# ...

# %%
X = df2[['Air temperature (°C)', 'Pressure (atm)', 'Wind speed (m/s)']]
Y = df2['Power generated by system (MW)']

# %%
threshold = 30

# %%
# Convert target variable to binary labels based on the threshold
Y_binary = (Y > threshold).astype(int)

# %%
# Split the dataset into train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y_binary, test_size=0.2, random_state=42)

# %%
# Define and train the logistic regression model
classifier = LogisticRegression()
classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
# Evaluate the model
Y_pred = classifier.predict(X_test)
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(Y_test, Y_pred))
# Out:
# Accuracy: 0.9958927552766685
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6889
#            1       0.99      0.99      0.99      1876
#
#     accuracy                           1.00      8765
#    macro avg       0.99      0.99      0.99      8765
# weighted avg       1.00      1.00      1.00      8765

# %%
df5 = pd.read_csv("/content/wind_power_gen_3months_validation_data.csv")

# %%
df5
# Out:
#                  DateTime  Air temperature | (°C)  Pressure | (atm)  \
# 0     2024-01-01 00:00:00                   6.609          0.988077
# 1     2024-01-01 01:00:00                   5.257          0.988969
# 2     2024-01-01 02:00:00                   4.374          0.989708
# 3     2024-01-01 03:00:00                   2.913          0.990171
# 4     2024-01-01 04:00:00                   1.152          0.990264
# ...                   ...                     ...               ...
# 2179  2024-03-31 19:00:00                  27.835          0.973886
# 2180  2024-03-31 20:00:00                  28.390          0.973506
# 2181  2024-03-31 21:00:00                  28.487          0.973034
# 2182  2024-03-31 22:00:00                  28.555          0.972540
# 2183  2024-03-31 23:00:00                  27.944          0.972353
#
#       Wind speed | (m/s)  Power generated by system | (MW)
# 0                 10.868                          53.18100
# ...

# %%
# Rename columns
df5.rename(columns={
    'Air temperature | (°C)': 'Air temperature (°C)',
    'Pressure | (atm)': 'Pressure (atm)',
    'Wind speed | (m/s)': 'Wind speed (m/s)',
    'Power generated by system | (MW)': 'Power generated by system (MW)'
}, inplace=True)

# %%
df5
# Out:
#                  DateTime  Air temperature (°C)  Pressure (atm)  \
# 0     2024-01-01 00:00:00                 6.609        0.988077
# 1     2024-01-01 01:00:00                 5.257        0.988969
# 2     2024-01-01 02:00:00                 4.374        0.989708
# 3     2024-01-01 03:00:00                 2.913        0.990171
# 4     2024-01-01 04:00:00                 1.152        0.990264
# ...                   ...                   ...             ...
# 2179  2024-03-31 19:00:00                27.835        0.973886
# 2180  2024-03-31 20:00:00                28.390        0.973506
# 2181  2024-03-31 21:00:00                28.487        0.973034
# 2182  2024-03-31 22:00:00                28.555        0.972540
# 2183  2024-03-31 23:00:00                27.944        0.972353
#
#       Wind speed (m/s)  Power generated by system (MW)
# 0               10.868                        53.18100
# 1               10.679                        51.90830
# ...

# %%
classifier.predict(df4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-c151ec89fe84> in <cell line: 1>()
# ----> 1 classifier.predict(df4)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     417         """
#     418         xp, _ = get_namespace(X)
# --> 419         scores = self.decision_function(X)
#     420         if len(scores.shape) == 1:
#     421             indices = xp.astype(scores > 0, int)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     398         xp, _ = get_namespace(X)
#     399
# --> 400         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     401         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#     402         return xp.reshape(scores, -1) if scores.shape[1] == 1 else scores
#
# ...

# %%
import pandas as pd

# Assume you have a DataFrame named 'df' with a column 'Power generated by system (MW)'
# You can replace 'df' with the actual name of your DataFrame

# Define the column containing the values to be split
power_column = df5['Power generated by system (MW)']

# Calculate the total number of values
total_values = len(power_column)

# Determine the number of values for each part based on the ratio
part1_count = int(total_values * 0.2)
part2_count = int(total_values * 0.45)
part3_count = total_values - part1_count - part2_count

# Split the values into three parts
power_gen1 = power_column[:part1_count]
power_gen2 = power_column[part1_count:part1_count + part2_count]
power_gen3 = power_column[part1_count + part2_count:]

# Create new columns in the existing DataFrame for the split values
df5['power_gen1'] = power_gen1
df5['power_gen2'] = power_gen2
df5['power_gen3'] = power_gen3

# Display the updated DataFrame
print(df5)
# Out:
#                  DateTime  Air temperature (°C)  Pressure (atm)  \
# 0     2024-01-01 00:00:00                 6.609        0.988077
# 1     2024-01-01 01:00:00                 5.257        0.988969
# 2     2024-01-01 02:00:00                 4.374        0.989708
# 3     2024-01-01 03:00:00                 2.913        0.990171
# 4     2024-01-01 04:00:00                 1.152        0.990264
# ...                   ...                   ...             ...
# 2179  2024-03-31 19:00:00                27.835        0.973886
# 2180  2024-03-31 20:00:00                28.390        0.973506
# 2181  2024-03-31 21:00:00                28.487        0.973034
# 2182  2024-03-31 22:00:00                28.555        0.972540
# 2183  2024-03-31 23:00:00                27.944        0.972353
#
#       Wind speed (m/s)  Power generated by system (MW)  power_gen1  \
# 0               10.868                        53.18100     53.1810
# ...

# %%
# Drop rows where both 'power_gen2' and 'power_gen3' are NaN
df5.dropna(subset=['power_gen1','power_gen2', 'power_gen3'], how='any', inplace=True)

# Reset the index
df5.reset_index(drop=True, inplace=True)

# Display the updated DataFrame
print(df5)
# Out:
# Empty DataFrame
# Columns: [DateTime, Air temperature (°C), Pressure (atm), Wind speed (m/s), Power generated by system (MW), power_gen1, power_gen2, power_gen3]
# Index: []

# %%
# Remove extra columns from df4
df4 = df4.drop(['DateTime', 'Power generated by system (MW)'], axis=1)

# Make predictions using the classifier
predictions = classifier.predict(df4)

# %%
predictions
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
import matplotlib.pyplot as plt

# Plot histogram of original and predicted labels
plt.hist(Y_test, alpha=0.5, label='Original')
plt.hist(Y_pred, alpha=0.5, label='Predicted')
plt.xlabel('Label')
plt.ylabel('Frequency')
plt.title('Comparison of Original and Predicted Labels')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a time series for demonstration (replace this with your actual time series data)
dates = pd.date_range(start='2022-01-01', end='2022-01-10', freq='D')
original_values = np.random.randint(0, 100, size=len(dates))
predicted_values = original_values + np.random.randint(-20, 20, size=len(dates))

# Create a DataFrame
data = pd.DataFrame({'Date': dates, 'Original': original_values, 'Predicted': predicted_values})
data.set_index('Date', inplace=True)

# Plot the line graph
plt.plot(data.index, data['Original'], label='Original', marker='o')
plt.plot(data.index, data['Predicted'], label='Predicted', marker='o')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Comparison of Original and Predicted Values over Time')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate original dataset (2019 to 2023)
dates_original = pd.date_range(start='2019-01-01', end='2023-12-31', freq='D')
values_original = np.random.randint(0, 100, size=len(dates_original))
original_data = pd.DataFrame({'Date': dates_original, 'Value': values_original})

# Generate new dataset (2024)
dates_new = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')
values_new = np.random.randint(0, 100, size=len(dates_new))
new_data = pd.DataFrame({'Date': dates_new, 'Value': values_new})

# Plot the line graph
plt.plot(original_data['Date'], original_data['Value'], label='Original', marker='o')
plt.plot(new_data['Date'], new_data['Value'], label='New', marker='o')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Comparison of Original and New Values over Time')
plt.legend()
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Assume you have a DataFrame named 'df' with a column 'Power generated by system (MW)'
# You can replace 'df' with the actual name of your DataFrame

# Define the column containing the values to be split
power_column = df4['Power generated by system (MW)']

# Calculate the total number of values
total_values = len(power_column)

# Determine the number of values for each part based on the ratio
part1_count = int(total_values * 0.2)
part2_count = int(total_values * 0.45)
part3_count = total_values - part1_count - part2_count

# Split the values into three parts
power_gen1 = power_column[:part1_count]
power_gen2 = power_column[part1_count:part1_count + part2_count]
power_gen3 = power_column[part1_count + part2_count:]

# Create new columns in the existing DataFrame for the split values
df4['power_gen1'] = power_gen1
df4['power_gen2'] = power_gen2
df4['power_gen3'] = power_gen3

# Display the updated DataFrame
print(df4)
